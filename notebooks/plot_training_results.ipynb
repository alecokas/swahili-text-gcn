# %% [markdown]
# ## Set work directory

# %%
import os
WORK_DIR = os.path.join(os.getenv("HOME"), 'text-gnn')
os.chdir(WORK_DIR)

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import sys
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

sys.path.append('src')
from src.gnn.utils.utils import load_training_log_to_df,create_training_plot
# Out:
# <style>.container { width:80% !important; }</style>

# %%
training_log_path = os.path.join(WORK_DIR,'results/gnn_results/train/train-log.jsonl')
training_history = load_training_log_to_df(training_log_path)

# %%
training_history
# Out:
#     epoch  train_epoch_duration  train_loss  val_loss f-score  accuracy
# 0       1            143.229882    1.790579  1.754415    None  0.456167
# 1       2            143.844719    1.753087  1.702881    None  0.456167
# 2       4            144.272344    1.633422  1.570402    None  0.460464
# 3       6            143.396027    1.491447  1.440440    None  0.465406
# 4       8            143.282548    1.388937  1.369913    None  0.474645
# 5      10            143.140395    1.337521  1.345302    None  0.518049
# 6      12            143.234116    1.306450  1.298626    None  0.596046
# 7      14            143.329597    1.239473  1.224339    None  0.633648
# 8      16            143.544624    1.148178  1.149256    None  0.647400
# 9      18            145.196519    1.081574  1.089957    None  0.657069
# 10     20            143.211557    1.023597  1.043062    None  0.660722
# 11     22            144.140229    0.970601  0.997315    None  0.677052
# 12     24            143.185452    0.906891  0.947480    None  0.690804
# 13     26            144.503183    0.857455  0.897841    None  0.697894
# 14     28            143.556005    0.812806  0.851958    None  0.706274
# 15     30            143.398824    0.755153  0.808838    None  0.721960
# 16     32            143.200403    0.717182  0.768712    None  0.746455
# 17     34            144.195616    0.669688  0.731575    None  0.775247
# 18     36            145.227672    0.621484  0.699191    None  0.791147
# 19     38            145.218952    0.580302  0.669222    None  0.799742
# 20     40            143.237209    0.557203  0.640234    None  0.809841
# 21     42            144.609229    0.506902  0.614361    None  0.811990
# 22     44            143.337065    0.478779  0.592524    None  0.813494
# 23     46            143.098126    0.458476  0.573710    None  0.819725
# 24     48            143.483303    0.436641  0.558136    None  0.827031
# 25     50            147.064440    0.415895  0.543032    None  0.834121
# 26     52            143.566432    0.384647  0.529237    None  0.832617
# 27     54            143.061601    0.367973  0.520881    None  0.833047
# 28     56            143.325487    0.346746  0.512374    None  0.833262
# 29     58            143.355725    0.344040  0.500721    None  0.836055
# 30     60            143.328547    0.312789  0.493215    None  0.840782

# %%
create_training_plot(training_history)
