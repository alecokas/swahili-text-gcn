# %% [markdown]
# ## Set work directory

# %%
import os
WORK_DIR = os.path.join(os.getenv("HOME"), 'text-gnn')
os.chdir(WORK_DIR)

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import sys
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

sys.path.append('src')
from src.gnn.utils.utils import load_training_log_to_df,create_training_plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:80% !important; }</style>

# %%
training_log_path = os.path.join(WORK_DIR,'results/gnn_results/train/train-log.jsonl')
training_history = load_training_log_to_df(training_log_path)

# %%
training_history
# Out:
#     epoch  train_epoch_duration  train_loss  val_loss f-score  accuracy
# 0       1            167.689107    1.834514  1.474912    None  0.651838
# 1       2            167.676352    1.450667  1.231287    None  0.646680
# 2       4            167.619086    1.042947  1.074066    None  0.635074
# 3       6            167.602355    0.876249  0.910788    None  0.663873
# 4       8            167.682572    0.640786  0.712100    None  0.779712
# 5      10            167.639640    0.479100  0.640903    None  0.844831
# 6      12            167.625163    0.430006  0.593358    None  0.843112
# 7      14            167.543977    0.318812  0.514740    None  0.843757
# 8      16            167.589489    0.227299  0.506453    None  0.830432
# 9      18            167.632235    0.202002  0.528717    None  0.822695
# 10     20            167.584674    0.179442  0.519874    None  0.827208
# 11     22            167.524208    0.152684  0.490060    None  0.841608
# ...

# %%
create_training_plot(training_history)
